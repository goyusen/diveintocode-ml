# %% [markdown]
# # 解答例：Week2 授業前課題2 ダミーデータの作成

# %% [markdown]
# **テキストの目的**
# - 数式演算ライブラリのNumPyに慣れる
# - グラフの表示に慣れる
#
# **どのように学ぶか**
# - ヒントに従いデータの作成と作図を行っていきます。

# %% [markdown]
# ## 【問題1】乱数の作成
#
# 平均が(-3, 0)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
# $$
# \left[
# \begin{array}{ccc}
#   1.0 & 0.8\\
#   0.8 & 1.0
# \end{array}
# \right]
# $$
#
# 多次元の正規分布による乱数はnp.random.multivariate_normal()を使うことで作成できます。
#
# [numpy.random.multivariate_normal — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.multivariate_normal.html)
#
# 作成したndarrayのshapeは(500, 2)になります。

# %% [markdown]
# 《シード値について》
#
# 実行ごとに値が変わらないように、np.random.seed()により乱数のシード値を固定しておきましょう。今回シード値は0を使うことにします。
#
# np.random.seed(0)

# %%
import numpy as np

np.random.seed(0)

# %%
n_samples = 500 # サンプル数を指定
cov = [[1, 0.8], [0.8, 1]] # 共分散行列を指定
mean01 = [-3, 0] # 平均を指定

data01 = np.random.multivariate_normal(mean01, cov, n_samples) # 共分散行列を作成

# %%
print(data01)
print(data01.shape)
# Out:
# [[-3.06062569 -0.52703394]
#  [-1.36414919  1.28024964]
#  [-1.7432655   1.77812447]
#  [-5.68360805 -2.04365465]
#  [-2.73847733  0.2720888 ]
#  [-3.9046783  -1.28473034]
#  [-2.4399092  -0.81232153]
#  [-1.76068927  0.87921078]
#  [-3.36086359 -0.84636759]
#  [-3.64466182 -0.52882049]
#  [-4.42382791 -2.10404309]
#  [-0.31360605  1.14480607]
#  [-3.22308633  0.50496578]
#  [-3.38403683  0.03241043]
#  [-3.02807804  0.12206618]
#  [-2.17705815  2.04508016]
#  [-3.04157859 -0.87375286]
#  [-1.30572215  2.03141977]
#  [-2.80673643  0.01416265]
#  [-4.18035628 -1.5399814 ]
#  [-2.42285495  1.03532524]
#  [-3.16679009 -0.9828212 ]
#  [-4.36901738 -0.12882663]
#  [-2.48953514  0.12617717]
#  [-2.57931684  0.95916129]
#  [-3.49139468 -1.19425726]
#  [-4.48281804 -0.67608985]
#  [-2.58830899 -0.9706541 ]
#  [-3.23783204 -1.26559847]
#  [-4.0226051  -0.38112499]
#  [-3.08198312 -1.73608893]
#  [-2.54403308  0.92556419]
#  [-2.43985508 -0.40428771]
#  [-2.58260186  0.41398816]
# ...

# %% [markdown]
# ## Scatter plotScatter plotScatter plotScatter plot【問題2】散布図による可視化
# 問題1で作成したデータ点を散布図により可視化してください。
#
# 散布図はmatplotlibのplt.scatter()を使うことで描けます。
#
# [matplotlib.pyplot.scatter — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("Scatter plot")
plt.xlabel("colume1")
plt.ylabel("colume2")
plt.tick_params(labelsize=16)
plt.scatter(data01[:, 0], data01[:, 1]) #data01[:, 0]は一列目、data01[:, 1]は2列目
plt.show()

# %% [markdown]
# ## 【問題3】ヒストグラムによる可視化
#
# 問題1で作成したデータをヒストグラムにより可視化してください。
#
# ヒストグラムはplt.hist()を使うことで描けます。
#
# [matplotlib.pyplot.hist — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html)
#
# 各次元ごとに作成し、2つのヒストグラムとしてください。
#
# それぞれのヒストグラムの横軸の範囲はplt.xlim()を用いて揃えるようにしてください。
#
# [matplotlib.pyplot.xlim — Matplotlib 3.1.1 documentation](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xlim.html)

# %%
data01_min = data01.min() #横軸の範囲指定：一番左
data01_max = data01.max() #横軸の範囲指定：一番右

plt.title("histogtam of colume1")
plt.xlabel("colume1")
plt.ylabel("frequency")
plt.hist(data01[:, 0], bins=50) #binsはヒストグラムの棒の幅,任意
plt.xlim([data01_min, data01_max])
plt.show()

plt.title("histogtam of colume2")
plt.xlabel("colume2")
plt.ylabel("frequency")
plt.hist(data01[:, 1], bins=50)
plt.xlim([data01_min, data01_max])
plt.show()

# %% [markdown]
# ## 【問題4】データの追加
#
# 新たに平均が(0, -3)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
# $$
# \left[
# \begin{array}{ccc}
#   1.0 & 0.8\\
#   0.8 & 1.0
# \end{array}
# \right]
# $$
#
# そして、問題1、4それぞれのデータをひとつの散布図として可視化してください。凡例として問題1のものは0、問題4のものは1を表示してください。

# %%
np.random.seed(0)

# %%
n_samples = 500 # サンプル数を指定
cov = [[1, 0.8], [0.8, 1]] # 共分散行列を指定
mean02 = [0, -3] # 平均を指定

data02 = np.random.multivariate_normal(mean02, cov, n_samples) # 共分散行列を作成

# %%
print(data02)
print(data02.shape)
# Out:
# [[-1.64696085e+00 -5.22847917e+00]
#  [-6.53283507e-02 -3.15224273e+00]
#  [-1.21271528e+00 -4.37818990e+00]
#  [ 1.74348391e+00 -2.30301337e+00]
#  [-4.37026621e-01 -2.63361754e+00]
#  [-1.15557651e-01 -2.61259409e+00]
#  [ 3.03149039e-01 -3.16640113e+00]
#  [-4.65352471e-01 -4.86016238e+00]
#  [ 4.50212994e-01 -2.44339889e+00]
#  [ 8.21206954e-01 -1.98295065e+00]
#  [-8.40196070e-01 -3.94353320e+00]
#  [ 4.31991706e-01 -2.82316033e+00]
#  [ 6.66762328e-01 -2.40678432e+00]
#  [ 4.61641313e-01 -2.67156935e+00]
#  [-2.21938258e+00 -5.73615954e+00]
#  [-2.60687655e-01 -3.17512503e+00]
#  [-1.60085045e+00 -5.22293042e+00]
#  [ 2.62312590e-01 -3.18672173e+00]
#  [-5.58382922e-01 -2.91957055e+00]
#  [ 7.80489398e-01 -2.36316653e+00]
#  [-7.98334854e-01 -3.80013440e+00]
#  [ 1.95807277e-01 -3.30456294e+00]
#  [-1.29821569e+00 -4.56966808e+00]
#  [ 3.61486566e-01 -2.82739660e+00]
#  [-1.29021649e+00 -3.55281499e+00]
#  [ 1.72955078e-01 -2.82288009e+00]
#  [-5.42465853e-01 -3.41864194e+00]
# ...

# %%
plt.title("Scatter plot")
plt.xlabel("colume1")
plt.ylabel("colume2")
plt.tick_params(labelsize=16)
plt.scatter(data01[:, 0], data01[:, 1], label="data01") #data01の一列目、2列目
plt.scatter(data02[:, 0], data02[:, 1], label="data02") #data02の一列目、2列目
plt.legend()
plt.show()

# %% [markdown]
# ## 【問題5】データの結合
#
# データはまとめておいた方が後々扱いやすいです。問題1、4で作成したndarrayを 結合 し、(1000, 2)のndarrayとしてください。結合はnp.concatenate()やnp.vstack()を使うことで行えます。
#
# [numpy.concatenate — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.concatenate.html)
#
# [numpy.vstack — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.vstack.html)

# %%
data_joined = np.concatenate([data01, data02], axis=0) #np.concatenate()による結合
print(data_joined)
print(data_joined.shape)
# Out:
# [[-3.06062569 -0.52703394]
#  [-1.36414919  1.28024964]
#  [-1.7432655   1.77812447]
#  ...
#  [ 0.16097492 -2.0561603 ]
#  [ 0.04315888 -3.59219562]
#  [ 1.26449012 -2.30539772]]
# (1000, 2)

# %%
data_joined02 = np.vstack([data01, data02])　#np.vstack()による結合
print(data_joined02)
print(data_joined02.shape)
# Out:
# [[-3.06062569 -0.52703394]
#  [-1.36414919  1.28024964]
#  [-1.7432655   1.77812447]
#  ...
#  [ 0.16097492 -2.0561603 ]
#  [ 0.04315888 -3.59219562]
#  [ 1.26449012 -2.30539772]]
# (1000, 2)

# %% [markdown]
# ## 【問題6】ラベル付け
#
# ひとまとめになった1000個のデータそれぞれに対して、問題1、4どちらで作成したものなのかを示す ラベル 付けを行ってください。問題1のものには0、問題4のものには1を対応させます。
#
# 0と1を含むラベルの列を新たに追加し、(1000, 3)のndarrayを作成してください。
#
# 機械学習に使用するデータセットはこのような形になっていることが多いです。

# %%
shape = (n_samples, 1)
label0 = np.zeros(shape)
label1 = np.ones(shape)

label_joined = np.vstack([label0, label1])

data_with_label = np.hstack([data_joined, label_joined])
print(data_with_label)
print(data_with_label.shape) #(1000, 3)になっているか確認
# Out:
# [[-3.06062569 -0.52703394  0.        ]
#  [-1.36414919  1.28024964  0.        ]
#  [-1.7432655   1.77812447  0.        ]
#  ...
#  [ 0.16097492 -2.0561603   1.        ]
#  [ 0.04315888 -3.59219562  1.        ]
#  [ 1.26449012 -2.30539772  1.        ]]
# (1000, 3)
